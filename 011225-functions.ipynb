# %%
def addition(n1,n2,n3):
    global add
    add = n1 + n2 + n3

# %%
a = eval(input('Enter the First'))
b = eval(input('Enter the Second'))
c = eval(input('Enter the Third'))
addition(a,b,c)
print(f'The sum is :{add}')
# Out:
# Enter the First 10
# Enter the Second 20
# Enter the Third 30
# The sum is :60

# %%
add
# Out:
# 1030

# %%
a
# Out:
# 12

# %% [markdown]
# ##### add

# %%
#wap to find area of triangle Area = pi*r*r
import math
pi_value = math.pi
radius = eval(input("Enter the radius: "))
area_cal(pi_value,radius)
print(f"The area of triangle is: {area}")
# Out:
# Enter the radius:  12
# The area of triangle is: 452.3893421169302

# %%
def area_cal(pi_value,radius):
    global area
    area = pi_value*radius*radius

# %%
#wap to flind area of rectangle Formula area = l*b
def rect_cal(l,b):
    global area2
    area2 = l*b

# %%
length = eval(input("Enter the length: "))
breadth = eval(input("Enter the breadth: "))
rect_cal(length,breadth)
print(f"The area of rectangle is: {area2}")
area_cal(3.142,12)
print(f"The area of triangle: {area}")
# Out:
# Enter the length:  20
# Enter the breadth:  20
# The area of rectangle is: 400
# The area of triangle: 452.448

# %%
summ=0 
def add1():
    global summ
    a=10
    b=20
    summ= summ+a
    print(summ)
add1()
# Out:
# 10

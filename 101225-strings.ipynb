# %% [markdown]
# ** representations**

# %%
s1 = 'python'
s2 = "python"
s3 = "I like 'python'"
s4 = 'I like "python"'
print(s1)
print(s2)
print(s3)
print(s4)
# Out:
# python
# python
# I like 'python'
# I like "python"

# %%
print(type(s1))
print(s1)
print(len(s1))
print(min(s1))
print(max(s1))
#print(sum(s1))
print(sorted(s1))
print(reversed(s1))
# Out:
# <class 'str'>
# python
# 6
# h
# y
# ['h', 'n', 'o', 'p', 't', 'y']
# ...

# %%
print(reversed(s4))

# %%
len(s1)
# Out:
# 6

# %%
for i in 'python':
    print(i,ord(i))
# Out:
# p 112
# y 121
# t 116
# h 104
# o 111
# n 110

# %%
print(sorted(s1,reverse=True))
# Out:
# ['y', 't', 'p', 'o', 'n', 'h']

# %% [markdown]
# **iterable**

# %%
for i in range(5,51,5):
    print(i,end=' ')
# Out:
# 5 10 15 20 25 30 35 40 45 50

# %%
for i in range(30,0,-3):
    print(i,end=' ')
# Out:
# 30 27 24 21 18 15 12 9 6 3

# %%
for i in range(2,41,4):
    print(i, end=' ')
# Out:
# 2 6 10 14 18 22 26 30 34 38

# %%
s5 = sorted(s4,reverse=True)
print(s5)
# Out:
# ['y', 't', 'p', 'o', 'n', 'l', 'k', 'i', 'h', 'e', 'I', '"', '"', ' ', ' ']

# %%
list(reversed(s1))
# Out:
# ['n', 'o', 'h', 't', 'y', 'p']

# %%
ans = reversed(s4)
for i in ans:
    print(i, end= ' ')
# Out:
# " n o h t y p "   e k i l   I

# %%
username = input("Enter your full name:")
for i in username:
    print(i, end=' ')
# Out:
# Enter your full name: Tejas Shankar Vaval
# T e j a s   S h a n k a r   V a v a l

# %% [markdown]
# **concatenation**

# %%
s1 = 'hi'
s2 = 'Hello'
s1+' '+ s2
# Out:
# 'hi Hello'

# %%
s1-s2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 s1-s2
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
s1/s2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 s1/s2
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
s2*s1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 s2*s1
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
s1*3
# Out:
# 'hihihi'

# %% [markdown]
# **index**
#
# - index will give an idea how to acess elemnts in a string
# -

# %%
ss1 = 'python'
ss1[0]
# Out:
# 'p'

# %%
ss1[-4]
# Out:
# 't'

# %%
name = 'Tejas Vaval'
name[0], name[7]
for i in range(0,len(name),1):
    print(i,name[i])
# Out:
# 0 T
# 1 e
# 2 j
# 3 a
# 4 s
# 5
# 6 V
# 7 a
# 8 v
# 9 a
# 10 l

# %%
sname = "Fvssc"
for i in range(0,len(sname),1):
    print(sname[i])
# Out:
# F
# v
# s
# s
# c

# %%
country = input("Enter your country:")
for i in range(0,len(country),1):
    print(country[i])
# Out:
# Enter your country: jhjlh kgkjhjkl
# j
# h
# j
# l
# h
#
# k
# g
# k
# j
# h
# j
# k
# l

# %% [markdown]
# **India India**
# - I,d,a,,I,d,a

# %%
country = input('Enter your country:')
for i in range(0,len(country),1):
    print(i)
    print(country[i])
    print(country)
# Out:
# Enter your country: India
# 0
# I
# India
# 1
# n
# India
# 2
# d
# India
# 3
# i
# India
# 4
# a
# India

# %%
country = 'Australia'
for i in country:
    print(i)
# Out:
# A
# u
# s
# t
# r
# a
# l
# i
# a

# %% [markdown]
# **wap to acept friend name and his country**

# %% [markdown]
# **wap to acept friend name and his country**

# %%
fname = input('Friend name:')
fcountry = input('Friends country:')

for i in range(0, len(fname),1):
    print(fname[i])
for i in range(0, len(fcountry), 1):
    print(fcountry[i])
# Out:
# Friend name: Max
# Friends country: Spain
# M
# a
# x
# S
# p
# a
# i
# n

# %%
fname = input('Friend name:')
fcountry = input('Friends country:')

for i in fname:
    print(i)

for i in fcountry:
    print(i)
# Out:
# Friend name: Max
# Friends country: Spain
# M
# a
# x
# S
# p
# a
# i
# n

# %% [markdown]
# **Tejas -- Sajet

# %%
my_name = input("Enter your name:")
friend_name = input("Enter your friend name:")

for i in range((len(my_name)-1),0, -1):
    print(friend_name[i])
    print(my_name[i])
# Out:
# Enter your name: Tejas
# Enter your friend name: Myron
# n
# s
# o
# a
# r
# j
# y
# e

# %%
my_name = input("Enter your name:")
friend_name = input("Enter your friend name:")
for i in friend_name:
    print(i)

for j in my_name:
    print(j)
# Out:
# Enter your name: Tejas
# Enter your friend name: Nick
# N
# i
# c
# k
# T
# e
# j
# a
# s

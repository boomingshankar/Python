# %%
#area = pi*r*r to find area of circle
pi = 3.142
radius = 50
area = pi*radius*radius
print(f'The area of circle is {area}')
# Out:
# The area of circle is 7855.0

# %%
print('The area of circle is {}'.format(area))
# Out:
# The area of circle is 7855.0

# %%
print('The area of circle is',area)
# Out:
# The area of circle is 7855.0

# %%
#formula pound = weight * 2.2 -- weight to pound coversion
weight= 
pound= weight*2.2
pound = round(pound,2)
print(f'The pound conversion for the given weight({weight}) is {pound}')
# Out:
# The pound conversion for the given weight(81) is 178.2

# %%
#Aus dollar to Indian Inr conversion
#formula is inr = aus*55
aus= 100
inr= aus*55
print(f'The inr equivalent to aus dollar({aus}) is {inr}')
# Out:
# The inr equivalent to aus dollar(100) is 5500

# %%
#Aus dollar to Indian Inr conversion
#formula is inr = aus*55
aus= input('Please enter your selected amount ')
inr= int(aus)*55
print(f'The inr equivalent to aus dollar({aus}) is {inr}')
# Out:
# Please enter your selected amount  100
# The inr equivalent to aus dollar(100) is 5500

# %%
name = 'Tejas' 
type(name)
# Out:
# str

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\shank\Documents\NareshIT\Python

# %%
input()
# Out:
#  python
# 'python'

# %%
input('Enter your name ')
# Out:
# Enter your name  Tejas
# 'Tejas'

# %%
input()
input()
input()
# Out:
#  Tejas Vaval
#  15
#  Brisbane
# 'Brisbane'

# %%
name = input('Enter your name :')
age = input('Enter your age :')
city = input('Enter your city :')

print(f'The name is {name}, My age is {age} and I live in {city}')
# Out:
# Enter your name : Tejas
# Enter your age : 15
# Enter your city : Brisbane
# The name is Tejas, My age is 15 and I live in Brisbane

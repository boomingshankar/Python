# %%
import string
dir(string)
string.ascii_lowercase
string.ascii_uppercase
string.digits
string.capwords('tejas vaval')
# Out:
# 'Tejas Vaval'

# %%
import random
random
# Out:
# <module 'random' from 'C:\\Users\\shank\\anaconda3\\Lib\\random.py'>

# %%
import flask

# %%
import streamlit

# %%
import langchain

# %%
import cv2

# %%
import langgraph

# %%
import tensorflow

# %%
LI=[1,2,3,4]

# %%
min(LI)
# Out:
# 1

# %%
max(LI)
# Out:
# 4

# %%
type(LI)
# Out:
# list

# %%
print(LI)
# Out:
# [1, 2, 3, 4]

# %%
len(LI)
# Out:
# 4

# %%
PI=3.142
radius=50
area=PI*radius*radius
print(area)
# Out:
# 7855.0

# %%
B_amount=20
T_amount=5
Total = B_amount+T_amount
print(Total)
# Out:
# 25

# %%
weight=10
pound=weight*2.2
print(pound)
# Out:
# 22.0

# %%
Aus=50
Inr=Aus*55
print(Inr)
# Out:
# 2750

# %%
Weight=50
Pound=Weight*2.2
print(Pound)
# Out:
# 110.00000000000001

# %%
Name='Tejas'
Mom='Jyoti'
Dad='Shankar'
print(Name)
print(Mom)
print(Dad)
# Out:
# Tejas
# Jyoti
# Shankar

# %%
friend_1 = "Nate"
friend_2 = "Myron"
friend_3 = "Max"
friend_4 = "Nick"
friend_5 = "Alessandro"

print(friend_1)
print(friend_2)
print(friend_3)
print(friend_4)
print(friend_5)
# Out:
# Nate
# Myron
# Max
# Nick
# Allesandro

# %%
friend_1
# Out:
# 'Nate'

# %%
friend_3
# Out:
# 'Max'

# %%
school_name = 'Fortitude Valley State Secondary Collage'
teacher_name = 'Toni Waters'
school_length = len(school_name)
print(school_length)
teacher_length = len(teacher_name)
print(teacher_length)
# Out:
# 40
# 11

# %%
print(len(school_name))
# Out:
# 40

# %%
print(school_length)
print(len(school_name))
# Out:
# 40
# 40

# %%
print(teacher_length)
print(len(teacher_name))
# Out:
# 11
# 11

# %%
sentence = "I joined in DS and ai class"
print(sentence)
# Out:
# I joined in DS and ai class

# %%
s2 = "I joined in \'DS and ai\' class"
print(s2)
# Out:
# I joined in 'DS and ai' class

# %%
f_name = 'My father\'s and mother\'s name'
print(f_name)
# Out:
# My father's and mother's name

# %%
school = 'My school is \"great\"'
print(school)
practice = 'Practise makes man "perfect"'
print(practice)
# Out:
# My school is "great"
# Practise makes man "perfect"

# %%
practise2 = "Practise makes man 'PERFECT'"
print(practise2)
# Out:
# Practise makes man 'PERFECT'

# %% [markdown]
# **Documents String**

# %% [markdown]
# """
# Documentation
# - Shankar Vaval
# - Tejas Vaval
# - shivaji vaval
# """

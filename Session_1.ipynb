# %%
import time
time.sleep(5)
print("Hi")

# %%
a=10
a

# %% [markdown]
# Short Cut
# To execute --> Shift + enter
# To change mode --> Esc + M --> MArkdown mode
# To Esc + Y --> Code mode

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\shank\\Documents\\NareshIT\\Python'

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\shank\\Documents\\NareshIT\\Python'

# %%
print("shankar Vaval")
# Out:
# shankar Vaval

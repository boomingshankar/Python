# %%
def greetings():
    print("HEllo Good evening")

# %%
greetings()
# Out:
# HEllo Good evening

# %%
def driver():
    print('Driver is ready')
    print('Driver arrived')

# %%
driver()
# Out:
# Driver is ready
# Driver arrived

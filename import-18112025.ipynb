# %%
import random
list = [11,2,3,4,5,5,6,7]
random.choice(list)
random.randint(20,60)
random.random()
random.choice(list)
random.shuffle(list)
print(f"List: {list}")
# Out:
# List: [5, 2, 11, 7, 6, 5, 4, 3]

# %%
import os
os.getcwd()
path = 'C:\\Users\\shank\\Documents\\NareshIT'
os.listdir(path)
# Out:
# ['Python', 'Tejas']

# %%
import random
std_list = ['max','Alesandro','nick','nate']
random.choice(std_list)
random.shuffle(std_list)
print(f'Student list are {std_list}')
# Out:
# Student list are ['nick', 'max', 'Alesandro', 'nate']

# %%
import math
math.e
math.pi
math.sqrt(16)
math.pow(5,2)
math.sin(180)
math.ceil(9.2)
# Out:
# 10

# %%
import math
math.pow(4,3)
# Out:
# 64.0

# %%
import os
os.getcwd()
os.listdir("C:\\Users\\shank\\Documents\\NareshIT\\Python")
#os.makedirs('Tej')
os.getcwd()
# Out:
# 'C:\\Users\\shank\\Documents\\NareshIT\\Python'

# %%
import os
path='C:\\Users\\shank\\Documents\\NareshIT\\Python\\Tej'
os.listdir(path)
# Out:
# []

# %%
import time
time.sleep(5)
print('Tejas')
# Out:
# Tejas

# %%
math.pow(5,2)
# Out:
# 25.0

# %%
import time
st_time = time.time()
time.sleep(7)
print("sleeping...")
end_time = time.time()
total_time_taken = end_time - st_time
print(f"Time total taken is {total_time_taken}")
# Out:
# sleeping...
# Time total taken is 7.001245021820068

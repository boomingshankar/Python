# %%
age = input("Enter your age: ")
age = int(age)
if age > 18:
    print("You are eligible to vote.")
else:
    print("Sorry you are underaged to vote.")
# Out:
# Enter your age:  15
# Sorry you are underaged to vote.

# %%
a = 10
b = 20
if a < b :
    c = a+b
    print(c)
# Out:
# 30

# %%
print("HI")
print("Hello")
if True:
    print("good evening")
print("YO")
# Out:
# HI
# Hello
# good evening
# YO

# %%
if True:
    print("HI")
    print("Hello")
else:
    print("Adios.")
# Out:
# HI
# Hello

# %%
if False:
    print("HI")
    print("Hello")
else:
    print("Adios.")
# Out:
# Adios.

# %%
if True:
    print("Hai")
    if True:
        print("Hello")
    else :
        print("Bye..")
# Out:
# Hai
# Hello

# %%
if True:
    print("Hai")
    if False:
        print("Hello")
    else :
        print("Bye..")
else:
    print("USA")
# Out:
# Hai
# Bye..

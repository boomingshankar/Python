# %%
def Average(n1,n2,n3=10):
    sum = n1+n2+n3
    avg = sum / 3
    return(sum,avg)
cal_average = Average(10,20,30)
print(cal_average)
# Out:
# (60, 20.0)

# %%
summ, avg = Average(2,4,5)

# %%
print(summ, avg)
# Out:
# 11 3.6666666666666665

# %%
def greet(name, age):
    print(f'My name is {name} and age is {age}')
greet('Tejas', 25)
greet('Teja', age=15)
# Out:
# My name is Tejas and age is 25
# My name is Teja and age is 15

# %%
greet(name='Teja', age=15)
# Out:
# My name is Teja and age is 15

# %%
greet(name='Teja', age)
import math
math.sin()
# Out:
#   Cell In[17], line 1
#     greet(name='Teja', age)
#                           ^
# SyntaxError: positional argument follows keyword argument

# %%
def greet1(name,*, age):
    print(f'My name is {name} and age is {age}')
#greet1('Tejas', 25) - Fails
#greet1('Tejas', age=25) -- works
#greet1(name='Tejas', 25) --fails
#greet1(name='Tejas', age=25) -- works

def greet2(name,/,age):
    print(f'My name is {name} and age is {age}')
#greet2('Tejas', age=22) -- Works
#greet2(name='Tejas', 25) --fails
#greet2('Tejas', 25) -- works
#greet2(name='Tejas', age=25) - Fails
# Out:
#   Cell In[31], line 11
#     greet2(name='Tejas', 25)
#                            ^
# SyntaxError: positional argument follows keyword argument

# %%
greet1(name='Teja', age=15)
# Out:
# My name is Teja and age is 15

# %%
greet1('Teja', age=15)
# Out:
# My name is Teja and age is 15

# %%
greet1(name='Teja', 15)
# Out:
#   Cell In[21], line 1
#     greet1(name='Teja', 15)
#                           ^
# SyntaxError: positional argument follows keyword argument
